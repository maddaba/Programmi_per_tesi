# %%
from astropy.table import Table
import numpy as np

tab = Table(rows=[
    ("CRATES J024445+132002",      8.928, -1.030, 0.000, 1.000),
    ("PKS 0446+112",              10.721, -2.022, 0.656, 0.344),
    ("NVSS J054341+062553",        7.780, -0.062, 0.000, 1.000),
    ("GB6 J1040+0617",             9.495, -2.029, 0.585, 0.415),
    ("3HSP J111706.2+201407",      8.322, -2.165, 0.906, 0.094),
    ("CRATES J130215+203911",      6.120, -0.076, 0.375, 0.625),
    ("3HSP J140449.6+65543",       8.910, -2.137, 0.906, 0.094),
    ("NVSS J213252+261143",        8.774, -1.365, 0.062, 0.938),
    ("MG3 J231144+2604",           9.762, -2.045, 0.844, 0.156),
    ("CRATES J232625+011147",      9.344, -2.085, 0.969, 0.031),
    ("PKS 0426-380",               7.432, -1.315, 0.312, 0.688),
    ("PKS 0723-008",               9.042, -2.120, 0.875, 0.125),
    ("PKS 1424-41",                np.nan, np.nan, np.nan, np.nan),
    ("PKS 1502+106",               7.231, -0.161, 0.094, 0.906),
    ("WISEA J223133.89+003312.8", 10.020, -2.032, 0.594, 0.406),
],
names=("nome_blazar", "massa_log", "mdot_log",
       "frazione_ADAF", "frazione_SS"))

print(tab)

tab.write("MCMC_articolo_table.tex", format="ascii.latex", overwrite=True)
# Out:
#        nome_blazar        massa_log mdot_log frazione_ADAF frazione_SS
# ------------------------- --------- -------- ------------- -----------
#     CRATES J024445+132002     8.928    -1.03           0.0         1.0
#              PKS 0446+112    10.721   -2.022         0.656       0.344
#       NVSS J054341+062553      7.78   -0.062           0.0         1.0
#            GB6 J1040+0617     9.495   -2.029         0.585       0.415
#     3HSP J111706.2+201407     8.322   -2.165         0.906       0.094
#     CRATES J130215+203911      6.12   -0.076         0.375       0.625
#      3HSP J140449.6+65543      8.91   -2.137         0.906       0.094
#       NVSS J213252+261143     8.774   -1.365         0.062       0.938
#          MG3 J231144+2604     9.762   -2.045         0.844       0.156
#     CRATES J232625+011147     9.344   -2.085         0.969       0.031
#              PKS 0426-380     7.432   -1.315         0.312       0.688
# ...
