# %%
from astropy.table import Table
import numpy as np

nomi = np.array([ 
    "J0021", "J0050", "J0059", "J0133", "J0508", "J0922",
    "J0922-Hb", "J1123", "J1329", "J1329-Hg", "J1745", "J1816",
    "J1816-HgII/CIII", "J2237", "J152422", "J170108"
])

M_BH = np.array([
    5.7e9, 2.291e8, 2.185e8, 2.036e9, 6.208e5, 3.643e10,
    2.993e10, 4.54e9, 2.984e10, 9.516e7, 2.657e9, 3.037e10,
    2.667e11, 1.767e9, 4.751e10, 1.302e9
])

mdot = np.array([
    7.394e-3, 4.436e-3, 1.341e-2, 1.022e-2, 1.260e+1, 9.795e-3,
    9.953e-3, 6.853e-3, 9.633e-3, 4.013e-2, 7.629e-3, 9.922e-3,
    9.741e-3, 7.084e-3, 1.137e-3, 5.701e-3
])

M_BH_13_6 = np.array([
    5.651e9, 2.177e8, 4.717e8, 9.298e7, 6.143e5, 9.768e6,
    1.025e7, 4.317e9, 2.214e8, 2.760e8, 3.204e9, 3.262e10,
    2.462e11, 1.916e9, 3.230e10, 1.251e9
])

mdot_13_6 = np.array([
    1.008e-2, 6.176e-3, 3.157e-2, 4.474e-2, 1.276e1, 1.960e-1,
    1.647e-1, 8.298e-3, 2.609e-2, 4.744e-2, 8.340e-3, 9.851e-3,
    9.923e-3, 8.301e-3, 1.256e-3, 5.320e-3
])

tab = Table(
    [nomi, M_BH, mdot, M_BH_13_6, mdot_13_6],
    names=("Blazar",  "M_BH", "mdot", "M_BH_13.6", "mdot_13.6")
)

print(
    f"{'Blazar':<15}"
    f"{'M_BH':>15}"
    f"{'mdot':>15}"
    f"{'M_BH_13.6':>15}"
    f"{'mdot_13.6':>15}"
)

print ( "-" * 75)

for row in tab:
    print(
        f"{row['Blazar']:<15}"
        f"{row['M_BH']:>15.3e}"
        f"{row['mdot']:>15.3e}"
        f"{row['M_BH_13.6']:>15.3e}"
        f"{row['mdot_13.6']:>15.3e}"
    )
# Out:
# Blazar                    M_BH           mdot      M_BH_13.6      mdot_13.6
# ---------------------------------------------------------------------------
# J0021                5.700e+09      7.394e-03      5.651e+09      1.008e-02
# J0050                2.291e+08      4.436e-03      2.177e+08      6.176e-03
# J0059                2.185e+08      1.341e-02      4.717e+08      3.157e-02
# J0133                2.036e+09      1.022e-02      9.298e+07      4.474e-02
# J0508                6.208e+05      1.260e+01      6.143e+05      1.276e+01
# J0922                3.643e+10      9.795e-03      9.768e+06      1.960e-01
# J0922-Hb             2.993e+10      9.953e-03      1.025e+07      1.647e-01
# J1123                4.540e+09      6.853e-03      4.317e+09      8.298e-03
# J1329                2.984e+10      9.633e-03      2.214e+08      2.609e-02
# J1329-Hg             9.516e+07      4.013e-02      2.760e+08      4.744e-02
# ...
