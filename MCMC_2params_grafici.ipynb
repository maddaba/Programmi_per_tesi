# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("risultati_MCMC.csv")
mass = df["m_median_Msun"].values
mdot = df["mdot_median"].values

plt.figure(figsize=(8,6))
plt.scatter(
    np.log10(mass),
    np.log10(mdot),
    s=80,
    alpha=0.8
)
"""
for _, row in df.iterrows():
    plt.annotate(
        row["Blazar"],
        (
            np.log10(row["m_median_Msun"]),
            np.log10(row["mdot_median"])
        ),
        fontsize=8,
        xytext=(4,4),
        textcoords="offset points"
    )
"""

plt.xlabel(r"$\log_{10}(M_{\rm BH}/M_\odot)$", fontsize=13)
plt.ylabel(r"$\log_{10}(\dot m)$", fontsize=13)
plt.tight_layout()
plt.show()
